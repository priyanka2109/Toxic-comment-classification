# %%
import pandas as pd

# %%
df=pd.read_csv('survey_results_public.csv')
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
#To choose specific number of rows and columns
pd.set_option('display.max_rows',100)

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
#To see a specific column
df.Age # or you can use df['Age']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3        25.0
# 4        31.0
#          ...
# 64456     NaN
# 64457     NaN
# 64458     NaN
# 64459     NaN
# 64460     NaN
# Name: Age, Length: 64461, dtype: float64

# %%
#To see multiple columns
df[['Age','Hobbyist']]
# Out:
#         Age Hobbyist
# 0       NaN      Yes
# 1       NaN       No
# 2       NaN      Yes
# 3      25.0      Yes
# 4      31.0      Yes
# ...     ...      ...
# 64456   NaN      Yes
# 64457   NaN      Yes
# 64458   NaN      Yes
# 64459   NaN      Yes
# 64460   NaN      Yes
#
# [64461 rows x 2 columns]

# %%
#To select multiple rows
df.iloc[[0,1]]
# Out:
#    Respondent                      MainBranch Hobbyist  Age Age1stCode  \
# 0           1  I am a developer by profession      Yes  NaN         13
# 1           2  I am a developer by profession       No  NaN         19
#
#   CompFreq  CompTotal  ConvertedComp         Country    CurrencyDesc  ...  \
# 0  Monthly        NaN            NaN         Germany   European Euro  ...
# 1      NaN        NaN            NaN  United Kingdom  Pound sterling  ...
#
#                    SurveyEase           SurveyLength Trans  \
# 0  Neither easy nor difficult  Appropriate in length    No
# 1                         NaN                    NaN   NaN
#
#                                       UndergradMajor WebframeDesireNextYear  \
# 0  Computer science, computer engineering, or sof...           ASP.NET Core
# 1  Computer science, computer engineering, or sof...                    NaN
#
#      WebframeWorkedWith                             WelcomeChange WorkWeekHrs  \
# ...

# %%
#To get specific rows and specific columns
df.loc[[0,1],['Age','Hobbyist']]
# Out:
#    Age Hobbyist
# 0  NaN      Yes
# 1  NaN       No

# %%
#To check for different categories(labels) of a column
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
#To see one persons record
df.loc[0]
# Out:
# Respondent                                                                      1
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# ...

# %%
#To see first person's hoobyist column value
df.loc[0,'Hobbyist'] #0th row persons hobby value
# Out:
# 'Yes'

# %%
#To see a range of rows and columns
df.loc[0:2,'Hobbyist':'CompFreq']
# Out:
#   Hobbyist  Age Age1stCode CompFreq
# 0      Yes  NaN         13  Monthly
# 1       No  NaN         19      NaN
# 2      Yes  NaN         15      NaN

# %%
df1=pd.read_csv('survey_results_schema.csv')

# %%
df1.set_index('Column',inplace=True)

# %%
df1
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
#To sort df on the basis of index
df1.sort_index()
df1
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
# to set up a filter
filt=(df['Country']=='United Kingdom')

# %%
print(filt)
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 64456    False
# 64457    False
# 64458    False
# 64459    False
# 64460    False
# Name: Country, Length: 64461, dtype: bool

# %%
#To display selected columns of the filtered data
df.loc[filt,['Age','Hobbyist','Country']]
# Out:
#         Age Hobbyist         Country
# 1       NaN       No  United Kingdom
# 9      22.0      Yes  United Kingdom
# 10     23.0      Yes  United Kingdom
# 15     45.0      Yes  United Kingdom
# 29      NaN      Yes  United Kingdom
# ...     ...      ...             ...
# 64247   NaN      Yes  United Kingdom
# 64253  21.0      Yes  United Kingdom
# 64279  67.0      Yes  United Kingdom
# 64422  23.0      Yes  United Kingdom
# 64432   NaN      Yes  United Kingdom
#
# [3896 rows x 3 columns]

# %% [markdown]
# # Editing rows and columns

# %%
df.columns=[x.upper() for x in df.columns]
df
# Out:
#        RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
#To replace soemthing 
df.columns=df.columns.str.replace(' ','_')

# %%
df.rename(columns={'UNDERGRADMAJOR':'UGMANJOR','SURVEYLENGTH':'SURVEY_LEN'},inplace=True)

# %%
df
# Out:
#        RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.loc[[0,2],['TRANS','COUNTRY']]
# Out:
#   TRANS             COUNTRY
# 0    No             Germany
# 2   NaN  Russian Federation

# %%
#To change particular row ,columns values
df.loc[[0,2],['TRANS','COUNTRY']]=[' ',' ']

# %% [markdown]
# # Apply,Map,Applymap, Replace

# %%
#APPLY: WE use it on series object, to set up a fucntion/apply something overwhole series
df.dtypes
# Out:
# RESPONDENT                        int64
# MAINBRANCH                       object
# HOBBYIST                         object
# AGE                             float64
# AGE1STCODE                       object
# COMPFREQ                         object
# COMPTOTAL                       float64
# CONVERTEDCOMP                   float64
# COUNTRY                          object
# CURRENCYDESC                     object
# CURRENCYSYMBOL                   object
# DATABASEDESIRENEXTYEAR           object
# DATABASEWORKEDWITH               object
# DEVTYPE                          object
# EDLEVEL                          object
# EMPLOYMENT                       object
# ETHNICITY                        object
# GENDER                           object
# JOBFACTORS                       object
# JOBSAT                           object
# JOBSEEK                          object
# LANGUAGEDESIRENEXTYEAR           object
# LANGUAGEWORKEDWITH               object
# ...

# %%
df['RESPONDENT'].apply(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-2ebf9abcc6ad> in <module>
# ----> 1 df['RESPONDENT'].apply(len)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# TypeError: object of type 'int' has no len()

# %%
def update_country(COUNTRY):
    return COUNTRY.upper()
df['COUNTRY'].apply(update_country)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-70a80fe17958> in <module>
#       1 def update_country(COUNTRY):
#       2     return COUNTRY.upper()
# ----> 3 df['COUNTRY'].apply(update_country)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-13-70a80fe17958> in update_country(COUNTRY)
#       1 def update_country(COUNTRY):
# ----> 2     return COUNTRY.upper()
#       3 df['COUNTRY'].apply(update_country)
#
# AttributeError: 'float' object has no attribute 'upper'

# %%
df['COUNTRY'].dtype=object
#df['COUNTRY']=[x.upper() for x in df['COUNTRY'] ]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5304                 else:
# -> 5305                     object.__setattr__(self, name, value)
#    5306             except (AttributeError, TypeError):
#
# AttributeError: can't set attribute
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-37fa7fa266fe> in <module>
# ----> 1 df['COUNTRY'].dtype=object
#       2 #df['COUNTRY']=[x.upper() for x in df['COUNTRY'] ]
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5313                         stacklevel=2,
#    5314                     )
# ...

# %%
df.apply(len)
# Out:
# RESPONDENT            64461
# MAINBRANCH            64461
# HOBBYIST              64461
# AGE                   64461
# AGE1STCODE            64461
#                       ...
# WEBFRAMEWORKEDWITH    64461
# WELCOMECHANGE         64461
# WORKWEEKHRS           64461
# YEARSCODE             64461
# YEARSCODEPRO          64461
# Length: 61, dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-4312d437d7fd> in <module>
# ----> 1 df.apply(pd.Series.min)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# ...

# %% [markdown]
# # Add/ Remove Coulumns/Rows

# %%
df['EXP']=df['AGE1STCODE']+' '+df['MAINBRANCH']
df
# Out:
#        RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
#TO APPEND A ROW
df=df.append({'HOBBYIST':'No'},ignore_index=True)

# %%
df.shape
# Out:
# (64462, 62)

# %%
#TO DROP A SPECIFIC ROW
df.drop(index=64461)
# Out:
#        RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 0             1.0                     I am a developer by profession      Yes
# 1             2.0                     I am a developer by profession       No
# 2             3.0                        I code primarily as a hobby      Yes
# 3             4.0                     I am a developer by profession      Yes
# 4             5.0  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456     64858.0                                                NaN      Yes
# 64457     64867.0                                                NaN      Yes
# 64458     64898.0                                                NaN      Yes
# 64459     64925.0                                                NaN      Yes
# 64460     65112.0                                                NaN      Yes
#
# ...

# %% [markdown]
# # Ways to sort dataset

# %%
df
# Out:
#        RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 0             1.0                     I am a developer by profession      Yes
# 1             2.0                     I am a developer by profession       No
# 2             3.0                        I code primarily as a hobby      Yes
# 3             4.0                     I am a developer by profession      Yes
# 4             5.0  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64457     64867.0                                                NaN      Yes
# 64458     64898.0                                                NaN      Yes
# 64459     64925.0                                                NaN      Yes
# 64460     65112.0                                                NaN      Yes
# 64461         NaN                                                NaN       No
#
# ...

# %%
df.to_csv('file1.csv')

# %%
#for sorting in ascending/descending order
df.sort_values(['HOBBYIST','EXP'],ascending=[True,False])#It will consider ascending order for hobbyist column only
# We do this becuase if values are same, we should give another parameter with which it can compare column for sorting
# Out:
#        RESPONDENT                                         MAINBRANCH HOBBYIST  \
# 1446       1452.0  I used to be a developer by profession, but no...       No
# 2266       2275.0  I used to be a developer by profession, but no...       No
# 11407     11445.0  I am not primarily a developer, but I write co...       No
# 31527     31646.0  I am not primarily a developer, but I write co...       No
# 31930     32049.0  I am not primarily a developer, but I write co...       No
# ...           ...                                                ...      ...
# 62785     64139.0             I am a student who is learning to code      NaN
# 62985     64354.0                     I am a developer by profession      NaN
# 63497     64915.0  I am not primarily a developer, but I write co...      NaN
# 63778     65217.0                     I am a developer by profession      NaN
# 63804     65245.0             I am a student who is learning to code      NaN
#
# ...

# %%
#TO FIND 10 LARGEST VALUES OF ANY COLUMNS
df['CONVERTEDCOMP'].nlargest(10)
# Out:
# 121     2000000.0
# 123     2000000.0
# 191     2000000.0
# 663     2000000.0
# 697     2000000.0
# 722     2000000.0
# 816     2000000.0
# 982     2000000.0
# 1018    2000000.0
# 1032    2000000.0
# Name: CONVERTEDCOMP, dtype: float64

# %% [markdown]
# # Grouping and Aggregating Data

# %%
df['CONVERTEDCOMP'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# RESPONDENT       32231.0
# AGE                 29.0
# COMPTOTAL        63000.0
# CONVERTEDCOMP    54049.0
# WORKWEEKHRS         40.0
# dtype: float64

# %%
#For grouping according to a column
country_group=df.groupby(['COUNTRY'])
country_group.get_group('Germany')
# Out:
#        RESPONDENT                              MAINBRANCH HOBBYIST   AGE  \
# 5             6.0          I am a developer by profession       No   NaN
# 22           23.0          I am a developer by profession      Yes  27.0
# 23           24.0          I am a developer by profession      Yes  45.0
# 33           34.0          I am a developer by profession      Yes  29.0
# 59           60.0  I am a student who is learning to code      Yes   NaN
# ...           ...                                     ...      ...   ...
# 64295     36284.0                                     NaN      Yes   NaN
# 64332     42558.0                                     NaN      Yes   NaN
# 64336     42851.0                                     NaN      Yes  43.0
# 64380     52163.0                                     NaN      Yes   NaN
# 64402     56263.0                                     NaN      Yes   NaN
#
#       AGE1STCODE COMPFREQ  COMPTOTAL  CONVERTEDCOMP  COUNTRY   CURRENCYDESC  \
# ...

# %%
country_group['AGE'].value_counts()
# Out:
# COUNTRY      AGE
# Afghanistan  23.0    5
#              22.0    3
#              25.0    3
#              15.0    2
#              20.0    2
#                     ..
# Zimbabwe     21.0    1
#              25.0    1
#              27.0    1
#              30.0    1
#              33.0    1
# Name: AGE, Length: 3697, dtype: int64

# %% [markdown]
# # Handling missing values

# %%
df.dropna()
# Out:
#        RESPONDENT                      MAINBRANCH HOBBYIST   AGE AGE1STCODE  \
# 9            10.0  I am a developer by profession      Yes  22.0         14
# 32           33.0  I am a developer by profession      Yes  39.0         14
# 41           42.0  I am a developer by profession       No  32.0         14
# 46           47.0  I am a developer by profession      Yes  53.0         10
# 68           69.0  I am a developer by profession      Yes  25.0         12
# ...           ...                             ...      ...   ...        ...
# 61613     62863.0  I am a developer by profession      Yes  30.0         11
# 61636     62886.0  I am a developer by profession      Yes  32.0         24
# 61654     62904.0  I am a developer by profession      Yes  33.0         24
# 61993     63288.0  I am a developer by profession       No  31.0         16
# 63517     64938.0  I am a developer by profession       No  33.0         13
#
# ...

# %%
#To replace 'NA' or missing by some value
df.replace('NA',np.nan)

# %%
#To check where missing values are present
df.isna()
# Out:
#        RESPONDENT  MAINBRANCH  HOBBYIST    AGE  AGE1STCODE  COMPFREQ  \
# 0           False       False     False   True       False     False
# 1           False       False     False   True       False      True
# 2           False       False     False   True       False      True
# 3           False       False     False  False       False      True
# 4           False       False     False  False       False      True
# ...           ...         ...       ...    ...         ...       ...
# 64457       False        True     False   True        True      True
# 64458       False        True     False   True        True      True
# 64459       False        True     False   True        True      True
# 64460       False        True     False   True        True      True
# 64461        True        True     False   True        True      True
#
#        COMPTOTAL  CONVERTEDCOMP  COUNTRY  CURRENCYDESC  ...  SURVEY_LEN  \
# ...

# %%
#To fill missing values with 0
df.fillna(0)

# %%
#TO CHECK datatypes of all cloumns
df.dtypes
# Out:
# RESPONDENT                      float64
# MAINBRANCH                       object
# HOBBYIST                         object
# AGE                             float64
# AGE1STCODE                       object
# COMPFREQ                         object
# COMPTOTAL                       float64
# CONVERTEDCOMP                   float64
# COUNTRY                          object
# CURRENCYDESC                     object
# CURRENCYSYMBOL                   object
# DATABASEDESIRENEXTYEAR           object
# DATABASEWORKEDWITH               object
# DEVTYPE                          object
# EDLEVEL                          object
# EMPLOYMENT                       object
# ETHNICITY                        object
# GENDER                           object
# JOBFACTORS                       object
# JOBSAT                           object
# JOBSEEK                          object
# LANGUAGEDESIRENEXTYEAR           object
# LANGUAGEWORKEDWITH               object
# ...

# %%
#To cast datatypes
df['AGE']=df['AGE'].astype(int)

# %%
#Finding unique values
df['AGE'].unique()
# Out:
# array([  nan,  25. ,  31. ,  36. ,  30. ,  22. ,  23. ,  49. ,  53. ,
#         27. ,  45. ,  32. ,  24. ,  40. ,  18. ,  39. ,  29. ,  16. ,
#         34. ,  19. ,  35. ,  20. ,  38. ,  57. ,  28. ,  17. ,  44. ,
#         21. ,  48. ,  26. ,  42. ,  55. ,  37. ,  50. ,  41. ,  64. ,
#         63. ,  33. ,  43. ,  51. ,  60. ,  59. ,  62. ,  69. ,  52. ,
#         46. ,  49.5,  56. ,  47. ,  15. ,  72. ,  13. ,  71. ,  54. ,
#         70. ,  11. ,  14. ,  61. ,  26.8,  86. ,  58. ,  67. ,  94. ,
#         65. ,  66. ,  84. ,  73. ,  78. ,  68. ,  99. ,  74. ,  12. ,
#         77. ,  15.5,  85. ,  76. ,  35.7,  32.5,  81. ,  23.8,  97. ,
#         96. ,  26.5,   3. ,  24.5,  14.7,  34.5,   5. ,   1. ,  20.5,
#         79. , 279. ,  22.5,  27.5,  32.8,  10. ,  89. ,  80. ,  98. ,
#         19.8,   7. ,  21.5,  31.5,  88. ,  39.5,  16.5,  75. ,  83. ,
#         23.4,  95. ,  14.5])
